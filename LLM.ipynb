# %% [markdown]
# <a href="https://colab.research.google.com/github/zineb-chgari/TP-Language-modeling/blob/main/LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers tensorflow

# %%
import tensorflow as tf
from transformers import TFGPT2LMHeadModel, GPT2Tokenizer

# %%
# Chargement du tokenizer et du modèle pré-entraîné GPT-2
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = TFGPT2LMHeadModel.from_pretrained("gpt2")

# %%
def generate_text(prompt, max_length=50, temperature=1.0, top_k=50):
    # Tokenisation du prompt
    input_ids = tokenizer.encode(prompt, return_tensors='tf')

    # Génération du texte à partir du modèle GPT-2
    output = model.generate(
        input_ids,
        max_length=max_length,
        temperature=temperature,
        top_k=top_k,
        do_sample=True,
        num_return_sequences=1,
        pad_token_id=tokenizer.eos_token_id
    )

    # Décodage du texte généré
    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
    return generated_text

# %%
prompt = "The future of AI is"
generated_text = generate_text(prompt, max_length=100)
print(generated_text)
# Out:
# The future of AI is about to get a lot tougher.
#
# When the computer is ready to say its goodbyes to human employees when it's fully programmed in a virtual environment: by next fall, the computers will have an important role in the development of AI.
#
# But a new report from the University of Illinois at Urbana-Champaign's Center for Human Intelligence (CHI), which is coordinating the study, has found that for its first five years of development the AI
